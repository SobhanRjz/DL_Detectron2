# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "# Import necessary modules\n",
#      10     "import logging\n",
#      11     "from pathlib import Path\n",
#      12     "import torch\n",
#      13     "from Config.basic_config import BASE_PATH, OUTPUT_PATH, DEVICE\n",
#      14     "from Config.basic_config import detectron2_logger as logger\n",
#      15     "from Config.detectron2_config import DetectronConfig\n",
#      16     "from Config.dataset_config import DatasetConfig\n",
#      17     "from DataSets.preprocess_COCO import COCOJsonProcessor\n",
#      18     "from Train import mainTrain"
#      19    ]
#      20   },
#      21   {
# ...
